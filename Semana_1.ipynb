# %% [markdown]
# <center>
# <h1> Introducción a la programación con Python </h1>
# <h2> Alberto Mario Ceballos Arroyo </h2>
# <h2>Ingeniero de Sistemas </h2>
# </center>

# %% [markdown]
# <center> <h1> Algunos aspectos metodológicos </h1> </center>
#
# - Para participar, preferiblemente escribir por el chat o levantar la mano (somos 150).
#
# - Recordemos que el temario está disponible si queremos adelantarnos un poco.
#
# - La evaluación es automática y se basa en los retos, el resto de actividades de la plataforma son opcionales pero muy recomendadas.
#
# - La autoevaluación estará disponible durante los últimos días de la primera semana.

# %% [markdown]
# <center> <img src="img/temario.png"/> </center>

# %% [markdown]
# <center> <h1> Mis recomendaciones como programador</h1> </center>
#
#
# - Fortalecer el inglés tanto y tan pronto como sea posible, ya que hay 10 veces más recursos de programación que en español.
#
# - Para dudas rápidas, Google. Para afianzar conocimientos, libros y otros contenidos estructurados.
#
# - Estar pendientes de todas las convocatorias, cursos y recursos que ofrece MINTIC: Mision TIC es solo el primer paso.
#
# - Revisar los cursos gratis que hay en plataformas como Platzi, edx, Coursera y... el buscador de Google.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <center> <h1> Enlaces de interés </h1> </center>
#
# - Enlace de la plataforma: https://lms.misiontic2022udea.com/login
#
# - Drive con los materiales de la semana 1: https://drive.google.com/drive/u/0/folders/1kM-F9QnLnCM411q87VFwBy1SLDpoxj-i
#
# - Wiki de Python con muchos recursos en español: https://wiki.python.org/moin/SpanishLanguage
#
# - Correo del docente: alceballosa@unal.edu.co
#
# - Correo de permanencia: permamenciamisiontic@udea.edu.co

# %% [markdown]
# <center> <h1> ¿Cómo nos podemos comunicar con las máquinas? </h1> </center>
#
# </br>
#
# - En la clase anterior observamos que las máquinas procesan *datos* codificados como 0 y 1 (el popular binario).
#
# <center><img src="img/binary.png"/></center>
#
# - Si quisiéramos dar órdenes de manera directa a un computador, tendríamos que ser capaces de traducir nuestras instrucciones al lenguaje de las máquinas de alguna manera.

# %% [markdown]
# <center> <h1> Los lenguajes de programación </h1> </center>
#
# </br>
#
# - Un lenguaje de programación es, en su definición más sencilla, un conjunto de palabras reservadas llamadas palabras clave que facilitan esta tarea.
#
# - Mediante los lenguajes de programación podemos elaborar algoritmos (instrucciones) que, una vez *compilados* o *interpretados*, actúan como órdenes para el ordenador.
#
# - Generalmente, escribimos nuestros algoritmos en archivos de texto con una extensión (lo que va después del punto) que depende del lenguaje (.c para C, .py para python, etc.).

# %% [markdown]
# <center> <h1> Tipos de lenguajes de programación </h1> </center>
#
# </br>
#
# - Hay centenares de lenguajes de programación, y estos se pueden clasificar (principalmente) de tres formas:
#     - De bajo y alto nivel.
#     - Compilados o interpretados.
#     - Fuerte o débilmente tipados.
#
# Nota: hay muchas más formas de clasificar los lenguajes de programación: campo de aplicación, paradigma funcional vs orientado a objetos, etc.

# %% [markdown]
# <center> <h1> Lenguajes de bajo y alto nivel </h1> </center>
#
# - Los lenguajes de bajo nivel son, por lo general, mucho más complicados y requieren más líneas de código para representar la misma instrucción. Ejemplos: C, Ensamblador.
#
# - Los lenguajes de alto nivel, por contra, tienen una curva de aprendizaje más amigable y requieren menos líneas de código. Ejemplos: Python, Java.
#
# Nota: la interpretación de "bajo" y "alto" nivel es muy subjetiva, para muchas personas solo lenguajes con la complejidad de Ensamblador son de bajo nivel.

# %% [markdown]
# <center>
#
# ![imagen-2.png](attachment:imagen-2.png)
#
# </center>
#
# Fuente: https://es.slideshare.net/arcangelsombra/python-vs-c-presentation

# %% [markdown]
# <center> <h1> Lenguajes compilados e interpretados </h1> </center>
#
# - Los lenguajes compilados a menudo requieren que un compilador transforme el código (nuestro archivo de texto) en un archivo ejecutable (como los .exe en el caso de Windows). Esta compilación a menudo involucra una optimización del código. Por ej.: C, C++.
#
# - Los lenguajes interpretados se ejecutan bajo un "intérprete" que traduce el código a una versión intermedia en tiempo real y lo ejecuta. A menudo, estos lenguajes de programación son más lentos. Por ej.: Python, Javascript.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <center> <h1> Lenguajes fuerte y débilmente tipados </h1> </center>
#
# - Los lenguajes fuertemente tipados a menudo exigen que el usuario defina de antemano el tipo de cada variable. Esto resulta en una mayor cantidad de carácteres por línea de código, pero facilita el proceso de compilación y resulta en una ejecución más rápida. Ejemplos: Java, C#.
#
# - Los lenguajes débilmente tipados no requieren que el usuario defina los tipos de las variables. El intérprete se encarga en tiempo real de inferir el tipo de dato de cada variable. Esto tiene un costo computacional que se refleja en la ejecución de los algoritmos. Ejemplos: Python, JavaScript.

# %% [markdown]
# <center> <h1>El lenguaje de programación Python </h1> </center>
#
#
# - Python es un lenguaje de programación que fue creado a finales de los 80 por Guido van Rossum. Su nombre fue inspirado por la comedia inglesa *Monty Python*.
#
# - Es un lenguaje de alto nivel, compilado y débilmente tipado. Tiene una sintáxis muy simple y se usa en muchos ámbitos: desde el cómputo científico (como lenguaje 'pegamento') hasta el desarrollo web.
#
# - Hoy se encuentra en la versión 3.9.5 y, por lo general, está bien usar cualquier versión a partir de la 3.5. Las versiones desde la 2.7 para abajo ya no tienen soporte. Para más información: https://www.python.org/doc/versions/
#
# <center><img height="50" width="50" src="img/python_logo.png"/></center>

# %% [markdown]
# <center> <h1>¿Y cómo instalo Python? </h1> </center>
#
#
# - La manera más sencilla es descargar [Anaconda](https://www.anaconda.com/products/individual) o [Miniconda](https://docs.conda.io/en/latest/miniconda.html) desde sus respectivas páginas web. Recuerden descargar una versión que tenga Python mayor o igual a 3.6 y que se ajuste a su sistema operativo (Linux, Windows, Mac | 32 o 64 bits).
#
# - Ambos son distribuciones de conda, un gestor de paquetes de Python que nos facilitará mucho la vida cuando estemos hablando de librerías en las últimas semanas.

# %% [markdown]
# <center> <h1> Entornos de desarrollo recomendados </h1> </center>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">Nombre</th>
#     <th class="tg-0pky">Categoría</th>
#     <th class="tg-0pky">Flexibilidad</th>
#     <th class="tg-0pky">Dificultad de uso</th>
#     <th class="tg-0pky">Tipos de archivo</th>
#     <th class="tg-0pky">Enlace</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">Spyder</td>
#     <td class="tg-0pky">Libre</td>
#     <td class="tg-0pky">Baja</td>
#     <td class="tg-0pky">Baja</td>
#       <td class="tg-0pky">Archivos de texto</td>
#     <td class="tg-0pky">Viene con Anaconda</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Repl.it</td>
#     <td class="tg-0pky">Gratuito</td>
#     <td class="tg-0pky">Baja</td>
#     <td class="tg-0pky">Baja</td>
#       <td class="tg-0pky">Archivos de texto</td>
#     <td class="tg-0pky">https://replit.com/</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Visual Studio Code</td>
#     <td class="tg-0pky">Libre</td>
#     <td class="tg-0pky">Alta</td>
#     <td class="tg-0pky">Moderada</td>
#       <td class="tg-0pky">Archivos de texto, Notebooks</td>
#     <td class="tg-0pky"> https://code.visualstudio.com/download </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">PyCharm</td>
#     <td class="tg-0pky">Propietario (gratis .edu.co)</td>
#     <td class="tg-0pky">Moderada</td>
#     <td class="tg-0pky">Moderada</td>
#     <td class="tg-0pky">Archivos de texto, Notebooks</td>
#     <td class="tg-0pky">https://www.jetbrains.com/community/education/</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Google Colab</td>
#     <td class="tg-0pky">Propietario (gratis)</td>
#     <td class="tg-0pky">Baja</td>
#     <td class="tg-0pky">Baja</td>
#     <td class="tg-0pky">Notebooks</td>
#     <td class="tg-0pky">https://colab.research.google.com/</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <center> <h1>Variables en Python </h1> </center>
#
# - Una variable es el nombre que se le asigna, dentro de un programa, a una posición en memoria. Al tener la dirección de esta posición podemos manipular su contenido.
#
# - Las variables **siempre** deben comenzar por un carácter estándar (a-z, A-Z) y no por un número o un cáracter especial.
#
# - De preferencia, evitar carácteres como la ñ, pues no son reconocidos en todos los sistemas de codificación de texto.
#
# - Se pueden usar dos convenciones de nombrado de variables: **snake_case** y **camelCase**. Ambas son válidas, pero es preferible usar solo una a la vez.

# %% [markdown]
# <img src="img/kw.PNG"/>
#
# http://conocepython.blogspot.com/p/las-variables.html

# %% [markdown]
# <center> <h1> ¿Cómo funcionan las variables en memoria?  </h1> </center>
#
# ![imagen.png](attachment:imagen.png)

# %%
a = 5
b = 3
c = 8

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
a = a + b * c

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
print(a)
# Out:
# 29

# %% [markdown]
# <center> <h1> ¿Y las constantes? </h1> </center>
#
# - En sí, Python no tiene constantes. Para indicar en nuestro código que estamos manejando una constante utilizamos mayúscula constante.

# %%
PI = 3.1416
USERNAME = "Alberto"

# %% [markdown]
# <center> <h1>Los tipos de datos en Python </h1> </center>
#
# Python tiene varios tipos de datos, entre ellos:
#
# - int: todos los números enteros, positivos y negativos.
#
# - float: números reales, con parte decimal, positivos y negativos.
#
# - str: datos de tipo texto (del inglés *string*).
#
# - bool: datos de tipo lógico, pueden ser verdadero o falso.
#
# Encontraremos muchos más durante el curso.

# %%
x = 1
print(x, "es de tipo", type(x))

x = 0
print(x, "es de tipo", type(x))

x = -20000
print(x, "es de tipo", type(x))

x = 2.0
print(x, "es de tipo", type(x))

x = "Mensaje"
print(x, "es de tipo", type(x))

x = "a"
print(x, "es de tipo", type(x))

x = True
print(x, "es de tipo", type(x))

x = False
print(x, "es de tipo", type(x))
# Out:
# 1 es de tipo <class 'int'>
# 0 es de tipo <class 'int'>
# -20000 es de tipo <class 'int'>
# 2.0 es de tipo <class 'float'>
# Mensaje es de tipo <class 'str'>
# a es de tipo <class 'str'>
# True es de tipo <class 'bool'>
# False es de tipo <class 'bool'>

# %% [markdown]
# <center> <h1> Operaciones de salida de datos </h1> </center>
#
# - La principal operación para salida de datos en Python es **print**.
#
# - Por el momento, la usaremos para mostrar datos por pantalla, pero se puede usar para escribir directamente en archivos también.
#
# - Esta tiene la siguiente forma básica:
#     - **print**(lista de variables y mensajes separados por coma)
#
#
# Nota: los mensajes deben ir encerrados entre comillas dobles o simples.

# %%
print ("Hola")
print ("mundo")
print ("Hola mundo")
print ("Hola", "mundo")
print ("Hola", end=" ")
print ("mundo")
print ("Hola","jóvenes","cómo","amanecen")
print ("Hola jóvenes cómo amanecen")
print ("Hola","jóvenes","cómo","amanecen", sep=",")
print ("Hola","jóvenes","\ncómo","amanecen", sep=", ")

# %%
a = 7 + 5
print(a)
print(7 + 5)
print(f"7 + 5 {a}")
# Out:
# 12
# 12
# 7 + 5 12

# %% [markdown]
# <center> <h1> Operaciones de entrada de datos </h1> </center>
#
# - La principal para entrar datos (leer) en un programa hecho en Python es **input**.
#
# - Ojo, esta no es la única forma de leer datos en Python.

# %%
nombre = input("Teclee su nombre ")
apellido = input(f"{nombre}, ahora teclee su apellido ")
print("Su nombre completo es", nombre, apellido, end=" ")
# Out:
# Teclee su nombre Alberto
# Alberto, ahora teclee su apellido Ceballos
# Su nombre completo es  Alberto Ceballos

# %%
edad = int(input(f"Muy bien, {nombre} {apellido}, ahora teclee su edad "))
qq = edad + 2
print(qq)

# %%
a = input("Entre número entero")
b = input("Entre otro número entero")
print(a+b)
