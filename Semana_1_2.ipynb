# %% [markdown]
# <center>
# <h1> Introducción a la programación con Python </h1>
# <h2> Alberto Mario Ceballos Arroyo </h2>
# <h2>Ingeniero de Sistemas </h2>
# </center>

# %% [markdown]
# <center> <h1> Instrucción de asignación </h1> </center>

# %%
x = 60
y = 10

z = x

print(f"x es {x}, z es {z}")


z = x**2/y

print(f"x^2/y es {z}")
# Out:
# x es 60, z es 60
# x^2/y es 360.0

# %%
x = y = z = 50
print(x,y,z)
# Out:
# 50 50 50

# %%
#Suma
x = 50
y = 60.0

string = "Me llamo Alberto."

print(x + y)

print(string + " Tengo tantos años.")
# Out:
# 110.0
# Me llamo Alberto. Tengo tantos años.

# %%
#Resta

x = 50 
y = 60

string = "Mensaje"

print(x-y)

#Las cadenas no soportan la resta.
# Out:
# -10

# %%
#Multiplicación

x = 50
y = 60

string = "Línea.\t"

z = x*y

print(z)

print( string*10 )
# Out:
# 3000
# Línea.	Línea.	Línea.	Línea.	Línea.	Línea.	Línea.	Línea.	Línea.	Línea.

# %%
# División

x = 60
y = 15

print(x/y)
# Out:
# 4.0

# %%
# División entera y el residuo

x = 55
y = 20
print(x/y)
print(x//y)

residuo = x%y
print(residuo)
# Out:
# 2.75
# 2
# 15

# %%
# Operadores lógicos

x = True
y = False

print(x and y)
# Out:
# False

# %%
# Aplicación del residuo

x = 40
es_par = (x%2 == 0)
print(es_par)
# Out:
# True

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <center> <h1> Expresiones aritméticas en Python </h1> </center>

# %%
a = 10
b = 5
c = 1
d = 0.5
e = 2
f = 8

expr1 = a + b*c/d - e**f

expr2 =  (a+b)*c//(d-e)**f

print(expr1)
print(expr2)
# Out:
# -236.0
# 0.0

# %%
a = 64
print("Correcto:",a**(1/2) )
print("Equivocado:", a**1/2)
# Out:
# Correcto: 8.0
# Equivocado: 32.0

# %%
a = 16
b = 8
c = 7
d = 5
e = 4
f = 2

# %%
expr1 = a + b * c//d - e**f

op1 = e**f
op2 = b*c//d
op3 = a + op2 - op1

print(op1)
print(op2)
print(op3, expr1)
# Out:
# 16
# 11
# 11 11

# %%
expr2 = (a+b)*c/(d-e)**f

op1 = a + b
op2 = d - e

op3 = op2**f

op4 = op1*c/op3

print(op4, expr2)
# Out:
# 168.0 168.0

# %%
e = 4
f = 2

# %%
expr3 = f**f**e

op1 = f**e
op2 = f**op1

print(op2, expr3)
# Out:
# 65536 65536

# %%
expr4 = (f**f)**e
op1 = f**f
op2 = op1**e
print(expr4, op2)
# Out:
# 256 256

# %%
expr = a + b * c//d - e**f

print(expr)
# Out:
# 11

# %%
a = 16
b = 8
c = 7
d = 5
e = 4
f = 2

# %%
expr5 = a*b//c*2

op1 = a*b
op2 = op1//c
op3 = op2*2

print(expr5, op3)
# Out:
# 36 36

# %%
expr6 = a/b/c*(d + e)/f ** e

op1 = d + e
op2 = (f**e)
op3 = a/b/c*op1/op2
print(op3, expr6)
# Out:
# 0.1607142857142857 0.1607142857142857

# %%
a = 16
b = 8
c = 7
d = 5
e = 4
f = 2

# %%
expr7 = a % b * e ** f 

op1 = e**f
op2 = a%b*op1
print(expr7, op2)
# Out:
# 0 0

# %%
16%7
# Out:
# 2

# %%
expr8 = c+d%e
op1 = d%e
op2 = c+op1
print(expr8,op2)
# Out:
# 8 8

# %%
d%e
# Out:
# 1

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
a = 1
b = 2
c = 1
d = 2
e = 2
f = 1
expr =  ( a + (b-c)/(d-a) - c/d  )/(a + b) - (  c/(d+a) + b**c**a )/(  (d+1)/(3+a)  )
print(expr)
# Out:
# -2.611111111111111

# %%
if (True or False):
    print("Hello, I’m ", 21, " years old")
# Out:
# Hello, I’m  21  years old

# %%
21 + "hola"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7495ea7ebb39> in <module>
# ----> 1 21 + "hola"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
